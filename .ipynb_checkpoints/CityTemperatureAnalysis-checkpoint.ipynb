# %%
import os
import pandas as pd
os.listdir(os.getcwd())
# Out:
# ['main.py',
#  'clima-detroit-hoy-etl.csv',
#  'output.log',
#  '.git',
#  'clima-detroit-hoy.csv',
#  '.ipynb_checkpoints',
#  'CityTemperatureAnalysis.ipynb',
#  'get-weather.sh',
#  'weather-site']

# %%
import csv
csv_file = 'clima-detroit-hoy.csv'
filtered_rows = []
with open(csv_file, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        if len(row)==30:
            filtered_rows.append(row)
len(filtered_rows)
# Out:
# 0

# %%
if filtered_rows:  # Esta condición es True si la lista no está vacía
    header = filtered_rows[0]
    data = filtered_rows[1:]
    print(len(header), len(data))
else:
    print("La lista filtered_rows está vacía. No se puede procesar.")
# Out:
# La lista filtered_rows está vacía. No se puede procesar.

# %%
df = pd.read_csv('clima-detroit-hoy.csv')
print(df.shape)
# Out:
# (181, 15)

# %%
df.sample(5)
# Out:
#                       dt  coord_lon  coord_lat weather_0description  \
# 112  2025-08-02 02:13:26   -83.0458    42.3314            clear sky
# 160  2025-08-03 01:27:24   -83.0458    42.3314            clear sky
# 102  2025-08-01 07:14:32   -83.0458    42.3314            clear sky
# 115  2025-08-02 02:56:13   -83.0458    42.3314            clear sky
# 156  2025-08-03 00:32:46   -83.0458    42.3314            clear sky
#
#      main_temp  main_feels_like  main_temp_min  main_temp_max  main_pressure  \
# 112      19.45            18.99          18.60          20.14           1026
# 160      20.95            20.72          19.45          22.06           1023
# 102      16.89            16.83          15.59          17.21           1024
# 115      18.99            18.54          17.26          19.99           1027
# 156      22.75            22.57          21.70          23.33           1023
#
#      main_humidity  wind_speed  wind_deg  clouds_all     city  cod
# ...

# %% [markdown]
# # Análisis de Datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   dt                    181 non-null    object
#  1   coord_lon             181 non-null    float64
#  2   coord_lat             181 non-null    float64
#  3   weather_0description  181 non-null    object
#  4   main_temp             181 non-null    float64
#  5   main_feels_like       181 non-null    float64
#  6   main_temp_min         181 non-null    float64
#  7   main_temp_max         181 non-null    float64
#  8   main_pressure         181 non-null    int64
#  9   main_humidity         181 non-null    int64
#  10  wind_speed            181 non-null    float64
#  11  wind_deg              181 non-null    int64
#  12  clouds_all            181 non-null    int64
#  13  city                  181 non-null    object
#  14  cod                   181 non-null    int64
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Crea la figura y el gráfico
df_etl = pd.read_csv('clima-detroit-hoy.csv')
# 2. Luego, ejecuta esta celda para crear tu gráfico
plt.figure(figsize=(10, 6))
df_etl.plot.line(x='dt', y='main_temp', ax=plt.gca())
plt.grid()
plt.title(f"Main Temp vs Time in {next(iter(set(df_etl.city)))}")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   dt                    181 non-null    object
#  1   coord_lon             181 non-null    float64
#  2   coord_lat             181 non-null    float64
#  3   weather_0description  181 non-null    object
#  4   main_temp             181 non-null    float64
#  5   main_feels_like       181 non-null    float64
#  6   main_temp_min         181 non-null    float64
#  7   main_temp_max         181 non-null    float64
#  8   main_pressure         181 non-null    int64
#  9   main_humidity         181 non-null    int64
#  10  wind_speed            181 non-null    float64
#  11  wind_deg              181 non-null    int64
#  12  clouds_all            181 non-null    int64
#  13  city                  181 non-null    object
#  14  cod                   181 non-null    int64
# ...

# %%
from datetime import datetime
df_etl = df.copy()

# Convierte la columna 'dt' de formato timestamp a datetime
df_etl['dt'] = pd.to_datetime(df_etl['dt'])

df_etl.sample(5)
# Out:
#                      dt  coord_lon  coord_lat weather_0description  main_temp  \
# 59  2025-08-01 05:55:53   -83.0458    42.3314            clear sky      17.55
# 22  2025-08-01 04:33:24   -83.0458    42.3314            clear sky      18.37
# 60  2025-08-01 05:55:53   -83.0458    42.3314            clear sky      17.55
# 91  2025-08-01 06:56:45   -83.0458    42.3314            clear sky      16.95
# 144 2025-08-02 20:41:13   -83.0458    42.3314            clear sky      25.27
#
#      main_feels_like  main_temp_min  main_temp_max  main_pressure  \
# 59             17.48          16.63          18.04           1024
# 22             18.33          17.25          18.97           1024
# 60             17.48          16.63          18.04           1024
# 91             16.87          16.07          17.22           1024
# 144            25.24          24.03          26.81           1024
#
#      main_humidity  wind_speed  wind_deg  clouds_all     city  cod
# ...

# %%
df_etl.describe().transpose()
# Out:
#                  count                           mean                  min  \
# dt                 181  2025-08-01 20:05:18.215469568  2025-08-01 03:48:20
# coord_lon        181.0                       -83.0458             -83.0458
# coord_lat        181.0                        42.3314              42.3314
# main_temp        181.0                      18.885138                15.05
# main_feels_like  181.0                      18.774972                 14.8
# main_temp_min    181.0                      17.678232                 13.9
# main_temp_max    181.0                      19.693204                16.21
# main_pressure    181.0                    1024.254144               1023.0
# main_humidity    181.0                       74.58011                 45.0
# wind_speed       181.0                       3.072265                  0.0
# wind_deg         181.0                     177.574586                  0.0
# ...

# %%
df_etl.to_csv('clima-detroit-hoy-etl.csv', index=False)

# %% [markdown]
# # Presentación resultados

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Crea la figura y el gráfico
plt.figure(figsize=(10, 6))
df_etl.plot.line(x='dt', y='main_temp', ax=plt.gca()) # Se usa 'x' y 'y' para claridad
# Añade la cuadrícula
plt.grid()
# Corrige el título usando la columna 'city'
plt.title(f'Main Temp vs Time in {next(iter(set(df_etl.city)))}')

# Muestra el gráfico
plt.show()

# %%
import plotly_express as px
import pandas as pd
fig = px.line(df_etl, x='dt', y=['main_temp', 'main_humidity'], 
              title=f"Main Temp & Humidity vs Time in {next(iter(set(df_etl.city)))}")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import plotly_express as px
#       2 import pandas as pd
#       3 fig = px.line(df_etl, x='dt', y=['main_temp', 'main_humidity'],
#       4               title=f"Main Temp & Humidity vs Time in {next(iter(set(df_etl.city)))}")
#
# ModuleNotFoundError: No module named 'plotly_express'

# %%
df_etl.main_temp.hist(bins=20)
plt.title(f'Histogram of Main Temp in {next(iter(set(df_etl.city)))}')
plt.grid()
plt.show()

# %%
fig = px.violin(df_etl, 'main_temp', 
              title=f"Violin Plot Main Temp in {next(iter(set(df_etl.city)))}")
              
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 fig = px.violin(df_etl, 'main_temp',
#       2               title=f"Violin Plot Main Temp in {next(iter(set(df_etl.city)))}")
#       4 fig.show()
#
# NameError: name 'px' is not defined

# %%
fig = plt.figure(figsize=(8,6))
plt.plot(df_etl['dt'], df_etl['main_temp'])
plt.grid()
plt.title(f'Main Temp vs Time in {next(iter(set(df_etl.city)))}')
fig.tight_layout()
fname = 'weather-site/content/images/temperature.png'
plt.savefig(fname)

# %%
#+begin_src python :results output graphics :file boxplot.svg
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5, 5))
tips = sns.load_dataset("tips")
sns.boxplot(x="day", y="tip", data=tips)
plt.show()
#+end_src
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 3
#       1 #+begin_src python :results output graphics :file boxplot.svg
#       2 import matplotlib.pyplot as plt
# ----> 3 import seaborn as sns
#       4 plt.figure(figsize=(5, 5))
#       5 tips = sns.load_dataset("tips")
#
# ModuleNotFoundError: No module named 'seaborn'
